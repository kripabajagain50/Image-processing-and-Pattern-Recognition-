# %% [markdown]
# <a href="https://colab.research.google.com/github/kripabajagain50/Image-processing-and-Pattern-Recognition-/blob/main/Untitledlab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# Read image
img = cv2.imread('Lenna.jpg', 0) / 255
cv2_imshow(img * 255)
print("Original Image")

# Generate Gaussian noise
noise = np.random.normal(0, 0.1, img.shape)
cv2_imshow((noise * 255).clip(0, 255))

print("Gaussian Noise")

# Add noise to image
noisy_img = img + noise
cv2_imshow((noisy_img * 255).clip(0, 255))
print("Noisy Image")
# Out:
# <PIL.Image.Image image mode=L size=105x70>
# Original Image
# <PIL.Image.Image image mode=L size=105x70>
# Gaussian Noise
# <PIL.Image.Image image mode=L size=105x70>
# Noisy Image
